# %% [markdown]
# ## **Name: Afrin Sadia, Id: 20-43666-2, Sec:F week-1 **

# %% [markdown]
# Number example

# %%
a= 23
b=4.3
c=5
a+b
# Out:
# 27.3

# %%
a-b

# %%
a*b

# %%
a/b-c

# %%
a+b+c

# %% [markdown]
# import math math.pi math.sqrt(a)

# %% [markdown]
# sqrt of the sum of a and b

# %%
import math
math.sqrt(a+b)

# %%
import random
random.random()
# Out:
# 0.8215872387969222

# %%
random.choice([1,4,6])
# Out:
# 4

# %%
a**2

# %% [markdown]
# mod of b

# %%
math.modf(b)

# %%
sin value of b

# %%
math.sin(a+b)

# %% [markdown]
# string example

# %%
st= 'IEEE AIUB Student Branch'
st
# Out:
# 'IEEE AIUB Student Branch'

# %% [markdown]
# length of the string

# %%
len(st)

# %% [markdown]
# last letter

# %%
st[-2]
# Out:
# 'B'

# %%
st[-6]
# Out:
# 'B'

# %%
st[1:-5]

# %% [markdown]
# concate new word

# %%
st + ' R10'

# %% [markdown]
# find a word in the string

# %%
st.find('dent')

# %% [markdown]
# replace a word

# %%
st.replace('IEEE','ieee')

# %% [markdown]
# Immutability

# %%
st='J'+st[1:]
st

# %%
st.split(' ')

# %%
st.upper()

# %%
st.lower()

# %% [markdown]
# how many string are there

# %%
st.count(st)

# %% [markdown]
# list example

# %%
list=[1,2.3, 'afrin', 'ai', 'cs', 'ieeer10']
len(list)
# Out:
# 6

# %%
list[1]
# Out:
# 2.3

# %% [markdown]
# add new iteam in list

# %%
list+['aiub', 'cse']
# Out:
# [1, 2.3, 'afrin', 'ai', 'cs', 'ieeer10', 'aiub', 'cse']

# %%
len(list)
# Out:
# 6

# %%
list.append('aiub')

# %%
len(list)

# %%
list

# %% [markdown]
# delete last one

# %%
del list[-1]
list
# Out:
# [1, 2.3, 'afrin', 'ai', 'cs']

# %% [markdown]
# dictionary

# %%
dis={'name':'afrin', 'id':'20-43666-2','dept':'CSE'}

# %%
dis
# Out:
# {'dept': 'CSE', 'id': '20-43666-2', 'name': 'afrin'}

# %%
dis['name']
# Out:
# 'afrin'

# %%
dis={'a':'10','x':'12','y':'14','z':'16'}

# %% [markdown]
# print keys

# %%
d=dis.keys()
d
# Out:
# dict_keys(['a', 'x', 'y', 'z'])

# %%
for key in d:
    print(key,'=>',dis[key])
# Out:
# a => 10
# x => 12
# y => 14
# z => 16

# %%
for key in sorted(d):
    print(key,'=>',dis[key])
# Out:
# a => 10
# x => 12
# y => 14
# z => 16

# %% [markdown]
# squre all value in a list

# %%
sq=[x**2 for x in [2,4,6]]
sq
# Out:
# [4, 16, 36]

# %% [markdown]
# touple

# %%
t=(2,3,5,7,8,9)
len(t)
# Out:
# 6

# %% [markdown]
# stack

# %%
info = [21, 'Manager', 89000,4.50, 'Dhaka']
info
# Out:
# [21, 'Manager', 89000, 4.5, 'Dhaka']

# %%
info.append(100)
print(info)
# Out:
# [21, 'Manager', 89000, 4.5, 'Dhaka', 100]

# %%
info.remove(4.5)
print(info)
# Out:
# [21, 'Manager', 89000, 'Dhaka', 100]

# %%
info.remove(89000)
print(info)
# Out:
# [21, 'Manager', 'Dhaka', 100]
